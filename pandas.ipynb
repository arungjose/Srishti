# %%
import pandas as pd

# %%
data = {'Name': ['Alice', 'Bob'], 'Age': [25,30]}
df = pd.DataFrame(data)

# %%
lst = [['Alice', 25], ['Bob', 30]]
df2 = pd.DataFrame(lst, columns = ['Name', 'Age'])

# %%
df.head()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   Age     2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 164.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df['Name']
# Out:
# 0    Alice
# 1      Bob
# Name: Name, dtype: object

# %%
df[['Name', 'Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
df[df['Age'] > 25]
# Out:
#   Name  Age
# 1  Bob   30

# %%
df['Gender'] = ['F', 'M']
df.drop('Age', axis=1, inplace=True)

# %%
df
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df.isnull()
# Out:
#     Name  Gender
# 0  False   False
# 1  False   False

# %%
df.dropna()
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df.fillna(0)
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df3.groupby('Gender')['Age'].mean()
# Out:
# Gender
# F    25.0
# M    30.0
# Name: Age, dtype: float64

# %%
df3 = pd.merge(df, df2, on='Name')

# %%
df.join(df3)

# %%
df = pd.read_csv('data.csv')

# %%
df.to_csv('output.csv', index=False)

# %%
df3.sort_values('Age')
# Out:
#     Name Gender  Age
# 0  Alice      F   25
# 1    Bob      M   30

# %%
df3['Age'].apply(lambda x: x+1)
# Out:
# 0    26
# 1    31
# Name: Age, dtype: int64

# %%
df3['Name'].unique()
# Out:
# array(['Alice', 'Bob'], dtype=object)

# %%
df3['Age'].value_counts()
# Out:
# Age
# 25    1
# 30    1
# Name: count, dtype: int64
